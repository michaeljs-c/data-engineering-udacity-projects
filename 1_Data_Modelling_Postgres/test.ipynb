# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7600c8b786e3> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# c:\users\michael.smithchandle\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-58> in load_ext(self, module_str)
#
# c:\users\michael.smithchandle\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays WHERE artist_id is not null;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 532 rows affected.
# [(0, datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 91, 'free', None, None, 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  (1, datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(91, 'Jayden', 'Bell', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (26, 'Ryan', 'Smith', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 189.57016),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148.03546)]

# %%
# %sql SELECT song_id, a.artist_id FROM songs s JOIN artists a on a.artist_id = s.artist_id \
WHERE title = 'Pink World' AND name = 'Planet P Project' AND duration = 269.81832
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B')]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', 'NaN'),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', 'NaN', 'NaN'),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', 'NaN', 'NaN'),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', 'NaN', 'NaN'),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', '35.14968', '-90.04892')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 0, 30, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 1, 30, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 1, 30, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 17, 5, 796000), 1, 30, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 20, 56, 796000), 1, 30, 11, 2018, 4)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
